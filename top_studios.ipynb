# %% [markdown]
# # what are the highest grossing studios?

# %%
#importing the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading the movie.gross.csv.gz file from zippedData to dataframe
movie_gross_df= pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
movie_gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movie_gross_df.shape
# Out:
# (3387, 5)

# %%
# checking for nullvalues
movie_gross_df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
# dropping null valued rows of domestic_gross column from dataframe
movie_gross_df.dropna(subset=['domestic_gross'])
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
# sorting the dataframe by Domestic_gross
movie_gross_df.sort_values(by=['domestic_gross'], ascending = False, inplace= True)

# %%
# printing to check top 10 movies 
movie_gross_df.head(10)
# Out:
#                              title studio  domestic_gross foreign_gross  year
# 1872  Star Wars: The Force Awakens     BV     936700000.0       1,131.6  2015
# 3080                 Black Panther     BV     700100000.0     646900000  2018
# 3079        Avengers: Infinity War     BV     678800000.0       1,369.5  2018
# 1873                Jurassic World   Uni.     652300000.0       1,019.4  2015
# 727          Marvel's The Avengers     BV     623400000.0     895500000  2012
# 2758      Star Wars: The Last Jedi     BV     620200000.0     712400000  2017
# 3082                 Incredibles 2     BV     608600000.0     634200000  2018
# 2323  Rogue One: A Star Wars Story     BV     532200000.0     523900000  2016
# 2759   Beauty and the Beast (2017)     BV     504000000.0     759500000  2017
# 2324                  Finding Dory     BV     486300000.0     542300000  2016

# %%
# grouping dataframe by studio since top 9 out of 10 are from same studio and assigning to new dataframe
top_studios_df = movie_gross_df.groupby(by ='studio').sum()

# %%
top_studios_df
# Out:
#         domestic_gross   year
# studio
# 3D           6100000.0   2010
# A23           164200.0   4024
# A24        324194200.0  98754
# ADC           248200.0   4032
# AF           2142900.0  12080
# ...                ...    ...
# XL            458000.0   4027
# YFG          1100000.0   2016
# Yash        31631400.0  28194
# Zee          1100000.0   2016
# Zeit.        5663500.0  32206
#
# [257 rows x 2 columns]

# %%
# sorting dataframe by total domestic gross
top_studios_df.sort_values(by =['domestic_gross'], inplace= True, ascending = False)

# %%
# resetting the index
top_studios_df= top_studios_df.reset_index()

# %%
top_studios_df
# Out:
#          studio  domestic_gross    year
# 0            BV    1.841903e+10  213451
# 1          Uni.    1.290239e+10  296082
# 2            WB    1.216805e+10  281941
# 3           Fox    1.094950e+10  273882
# 4          Sony    8.459683e+09  221575
# ..          ...             ...     ...
# 252         ALP    2.800000e+03    2011
# 253  Synergetic    2.400000e+03    2018
# 254          DR    8.000000e+02    2014
# 255        Myr.    0.000000e+00    2012
# 256          PI    0.000000e+00    2013
#
# [257 rows x 3 columns]

# %%
# plotting top 10 studios 
sns.barplot(y='domestic_gross', x ='studio', data = top_studios_df[0:10], color='blue')
plt.title("Top 10 Studios with Highest Domestic Gross")
# Out:
# Text(0.5, 1.0, 'Top 10 Studios with Highest Domestic Gross')

# %% [markdown]
# Conclusion:
# Top 3 studios which as highest domestic gross are Buena Vista, Universal and Warner Bros
